# %% [markdown]
# ### Dataset example inspection notebook
#
# This notebook shares a summary of dataset contents, and provides a visual comparision of two user defined examples against eachother.
#
# Requires knowledge of the dataset. Does not currentl work with all Qoherent datasets and is therefore a work in progress.

# %%
#Import dependancies
import matplotlib.pyplot as plt
import numpy as np
import pickle
from pathlib import Path
import random

# %%
# Select and load dataset files

path = Path.cwd()

# filename1 = "datasets_Qoherent_Modrec_Dataset_Unimpaired.dat"   #path to unimpaired dataset - uncomment to choose this dataset
filename1 = "datasets_Qoherent_Modrec_Dataset_AGWN.dat"   #path to AGWN dataset - uncomment to choose this dataset
# filename1 = "datasets_example-simple-dataset.dat"  #path to simple low footprint dataset - uncomment to choose this dataset

with open((path/filename1).resolve().as_posix(), 'rb') as f:
    X1 = pickle.load(f, encoding='bytes')
    try:
        for i in range(10):
            X2 = pickle.load(f, encoding='bytes')
            X1 = {**X1,**X2}
            X2 = None      
        
    except:
        None

# %%
#list the keys in the dataset
list(X1.keys())
# Out:
# [('bpsk', -20),
#  ('bpsk', -19),
#  ('bpsk', -18),
#  ('bpsk', -17),
#  ('bpsk', -16),
#  ('bpsk', -15),
#  ('bpsk', -14),
#  ('bpsk', -13),
#  ('bpsk', -12),
#  ('bpsk', -11),
#  ('bpsk', -10),
#  ('bpsk', -9),
#  ('bpsk', -8),
#  ('bpsk', -7),
#  ('bpsk', -6),
#  ('bpsk', -5),
#  ('bpsk', -4),
#  ('bpsk', -3),
#  ('bpsk', -2),
#  ('bpsk', -1),
#  ('bpsk', 0),
#  ('bpsk', 1),
#  ('bpsk', 2),
#  ('bpsk', 3),
#  ('bpsk', 4),
#  ('bpsk', 5),
#  ('bpsk', 6),
#  ('bpsk', 7),
#  ('bpsk', 8),
#  ('bpsk', 9),
#  ('bpsk', 10),
#  ('bpsk', 11),
#  ('bpsk', 12),
#  ('bpsk', 13),
#  ('bpsk', 14),
#  ('bpsk', 15),
#  ('bpsk', 16),
#  ('bpsk', 17),
#  ('bpsk', 18),
#  ('bpsk', 19),
#  ('bpsk', 20),
#  ('qpsk', -20),
#  ('qpsk', -19),
#  ('qpsk', -18),
#  ('qpsk', -17),
#  ('qpsk', -16),
#  ('qpsk', -15),
#  ('qpsk', -14),
#  ('qpsk', -13),
#  ('qpsk', -12),
#  ('qpsk', -11),
#  ('qpsk', -10),
#  ('qpsk', -9),
#  ('qpsk', -8),
#  ('qpsk', -7),
#  ('qpsk', -6),
#  ('qpsk', -5),
#  ('qpsk', -4),
#  ('qpsk', -3),
#  ('qpsk', -2),
#  ('qpsk', -1),
#  ('qpsk', 0),
#  ('qpsk', 1),
#  ('qpsk', 2),
#  ('qpsk', 3),
#  ('qpsk', 4),
#  ('qpsk', 5),
#  ('qpsk', 6),
#  ('qpsk', 7),
#  ('qpsk', 8),
#  ('qpsk', 9),
#  ('qpsk', 10),
#  ('qpsk', 11),
#  ('qpsk', 12),
#  ('qpsk', 13),
#  ('qpsk', 14),
#  ('qpsk', 15),
#  ('qpsk', 16),
#  ('qpsk', 17),
#  ('qpsk', 18),
#  ('qpsk', 19),
#  ('qpsk', 20),
#  ('8psk', -20),
#  ('8psk', -19),
#  ('8psk', -18),
#  ('8psk', -17),
#  ('8psk', -16),
#  ('8psk', -15),
#  ('8psk', -14),
#  ('8psk', -13),
#  ('8psk', -12),
#  ('8psk', -11),
#  ('8psk', -10),
#  ('8psk', -9),
#  ('8psk', -8),
#  ('8psk', -7),
#  ('8psk', -6),
#  ('8psk', -5),
#  ('8psk', -4),
#  ('8psk', -3),
#  ('8psk', -2),
#  ('8psk', -1),
#  ('8psk', 0),
#  ('8psk', 1),
#  ('8psk', 2),
#  ('8psk', 3),
#  ('8psk', 4),
#  ('8psk', 5),
#  ('8psk', 6),
#  ('8psk', 7),
#  ('8psk', 8),
#  ('8psk', 9),
#  ('8psk', 10),
#  ('8psk', 11),
#  ('8psk', 12),
#  ('8psk', 13),
#  ('8psk', 14),
#  ('8psk', 15),
#  ('8psk', 16),
#  ('8psk', 17),
#  ('8psk', 18),
#  ('8psk', 19),
#  ('8psk', 20),
#  ('pam4', -20),
#  ('pam4', -19),
#  ('pam4', -18),
#  ('pam4', -17),
#  ('pam4', -16),
#  ('pam4', -15),
#  ('pam4', -14),
#  ('pam4', -13),
#  ('pam4', -12),
#  ('pam4', -11),
#  ('pam4', -10),
#  ('pam4', -9),
#  ('pam4', -8),
#  ('pam4', -7),
#  ('pam4', -6),
#  ('pam4', -5),
#  ('pam4', -4),
#  ('pam4', -3),
#  ('pam4', -2),
#  ('pam4', -1),
#  ('pam4', 0),
#  ('pam4', 1),
#  ('pam4', 2),
#  ('pam4', 3),
#  ('pam4', 4),
#  ('pam4', 5),
#  ('pam4', 6),
#  ('pam4', 7),
#  ('pam4', 8),
#  ('pam4', 9),
#  ('pam4', 10),
#  ('pam4', 11),
#  ('pam4', 12),
#  ('pam4', 13),
#  ('pam4', 14),
#  ('pam4', 15),
#  ('pam4', 16),
#  ('pam4', 17),
#  ('pam4', 18),
#  ('pam4', 19),
#  ('pam4', 20),
#  ('qam16', -20),
#  ('qam16', -19),
#  ('qam16', -18),
#  ('qam16', -17),
#  ('qam16', -16),
#  ('qam16', -15),
#  ('qam16', -14),
#  ('qam16', -13),
#  ('qam16', -12),
#  ('qam16', -11),
#  ('qam16', -10),
#  ('qam16', -9),
#  ('qam16', -8),
#  ('qam16', -7),
#  ('qam16', -6),
#  ('qam16', -5),
#  ('qam16', -4),
#  ('qam16', -3),
#  ('qam16', -2),
#  ('qam16', -1),
#  ('qam16', 0),
#  ('qam16', 1),
#  ('qam16', 2),
#  ('qam16', 3),
#  ('qam16', 4),
#  ('qam16', 5),
#  ('qam16', 6),
#  ('qam16', 7),
#  ('qam16', 8),
#  ('qam16', 9),
#  ('qam16', 10),
#  ('qam16', 11),
#  ('qam16', 12),
#  ('qam16', 13),
#  ('qam16', 14),
#  ('qam16', 15),
#  ('qam16', 16),
#  ('qam16', 17),
#  ('qam16', 18),
#  ('qam16', 19),
#  ('qam16', 20),
#  ('qam64', -20),
#  ('qam64', -19),
#  ('qam64', -18),
#  ('qam64', -17),
#  ('qam64', -16),
#  ('qam64', -15),
#  ('qam64', -14),
#  ('qam64', -13),
#  ('qam64', -12),
#  ('qam64', -11),
#  ('qam64', -10),
#  ('qam64', -9),
#  ('qam64', -8),
#  ('qam64', -7),
#  ('qam64', -6),
#  ('qam64', -5),
#  ('qam64', -4),
#  ('qam64', -3),
#  ('qam64', -2),
#  ('qam64', -1),
#  ('qam64', 0),
#  ('qam64', 1),
#  ('qam64', 2),
#  ('qam64', 3),
#  ('qam64', 4),
#  ('qam64', 5),
#  ('qam64', 6),
#  ('qam64', 7),
#  ('qam64', 8),
#  ('qam64', 9),
#  ('qam64', 10),
#  ('qam64', 11),
#  ('qam64', 12),
#  ('qam64', 13),
#  ('qam64', 14),
#  ('qam64', 15),
#  ('qam64', 16),
#  ('qam64', 17),
#  ('qam64', 18),
#  ('qam64', 19),
#  ('qam64', 20),
#  ('gfsk', -20),
#  ('gfsk', -19),
#  ('gfsk', -18),
#  ('gfsk', -17),
#  ('gfsk', -16),
#  ('gfsk', -15),
#  ('gfsk', -14),
#  ('gfsk', -13),
#  ('gfsk', -12),
#  ('gfsk', -11),
#  ('gfsk', -10),
#  ('gfsk', -9),
#  ('gfsk', -8),
#  ('gfsk', -7),
#  ('gfsk', -6),
#  ('gfsk', -5),
#  ('gfsk', -4),
#  ('gfsk', -3),
#  ('gfsk', -2),
#  ('gfsk', -1),
#  ('gfsk', 0),
#  ('gfsk', 1),
#  ('gfsk', 2),
#  ('gfsk', 3),
#  ('gfsk', 4),
#  ('gfsk', 5),
#  ('gfsk', 6),
#  ('gfsk', 7),
#  ('gfsk', 8),
#  ('gfsk', 9),
#  ('gfsk', 10),
#  ('gfsk', 11),
#  ('gfsk', 12),
#  ('gfsk', 13),
#  ('gfsk', 14),
#  ('gfsk', 15),
#  ('gfsk', 16),
#  ('gfsk', 17),
#  ('gfsk', 18),
#  ('gfsk', 19),
#  ('gfsk', 20),
#  ('am-ssb', -20),
#  ('am-ssb', -19),
#  ('am-ssb', -18),
#  ('am-ssb', -17),
#  ('am-ssb', -16),
#  ('am-ssb', -15),
#  ('am-ssb', -14),
#  ('am-ssb', -13),
#  ('am-ssb', -12),
#  ('am-ssb', -11),
#  ('am-ssb', -10),
#  ('am-ssb', -9),
#  ('am-ssb', -8),
#  ('am-ssb', -7),
#  ('am-ssb', -6),
#  ('am-ssb', -5),
#  ('am-ssb', -4),
#  ('am-ssb', -3),
#  ('am-ssb', -2),
#  ('am-ssb', -1),
#  ('am-ssb', 0),
#  ('am-ssb', 1),
#  ('am-ssb', 2),
#  ('am-ssb', 3),
#  ('am-ssb', 4),
#  ('am-ssb', 5),
#  ('am-ssb', 6),
#  ('am-ssb', 7),
#  ('am-ssb', 8),
#  ('am-ssb', 9),
#  ('am-ssb', 10),
#  ('am-ssb', 11),
#  ('am-ssb', 12),
#  ('am-ssb', 13),
#  ('am-ssb', 14),
#  ('am-ssb', 15),
#  ('am-ssb', 16),
#  ('am-ssb', 17),
#  ('am-ssb', 18),
#  ('am-ssb', 19),
#  ('am-ssb', 20),
#  ('nbfm', -20),
#  ('nbfm', -19),
#  ('nbfm', -18),
#  ('nbfm', -17),
#  ('nbfm', -16),
#  ('nbfm', -15),
#  ('nbfm', -14),
#  ('nbfm', -13),
#  ('nbfm', -12),
#  ('nbfm', -11),
#  ('nbfm', -10),
#  ('nbfm', -9),
#  ('nbfm', -8),
#  ('nbfm', -7),
#  ('nbfm', -6),
#  ('nbfm', -5),
#  ('nbfm', -4),
#  ('nbfm', -3),
#  ('nbfm', -2),
#  ('nbfm', -1),
#  ('nbfm', 0),
#  ('nbfm', 1),
#  ('nbfm', 2),
#  ('nbfm', 3),
#  ('nbfm', 4),
#  ('nbfm', 5),
#  ('nbfm', 6),
#  ('nbfm', 7),
#  ('nbfm', 8),
#  ('nbfm', 9),
#  ('nbfm', 10),
#  ('nbfm', 11),
#  ('nbfm', 12),
#  ('nbfm', 13),
#  ('nbfm', 14),
#  ('nbfm', 15),
#  ('nbfm', 16),
#  ('nbfm', 17),
#  ('nbfm', 18),
#  ('nbfm', 19),
#  ('nbfm', 20),
#  ('wbfm', -20),
#  ('wbfm', -19),
#  ('wbfm', -18),
#  ('wbfm', -17),
#  ('wbfm', -16),
#  ('wbfm', -15),
#  ('wbfm', -14),
#  ('wbfm', -13),
#  ('wbfm', -12),
#  ('wbfm', -11),
#  ('wbfm', -10),
#  ('wbfm', -9),
#  ('wbfm', -8),
#  ('wbfm', -7),
#  ('wbfm', -6),
#  ('wbfm', -5),
#  ('wbfm', -4),
#  ('wbfm', -3),
#  ('wbfm', -2),
#  ('wbfm', -1),
#  ('wbfm', 0),
#  ('wbfm', 1),
#  ('wbfm', 2),
#  ('wbfm', 3),
#  ('wbfm', 4),
#  ('wbfm', 5),
#  ('wbfm', 6),
#  ('wbfm', 7),
#  ('wbfm', 8),
#  ('wbfm', 9),
#  ('wbfm', 10),
#  ('wbfm', 11),
#  ('wbfm', 12),
#  ('wbfm', 13),
#  ('wbfm', 14),
#  ('wbfm', 15),
#  ('wbfm', 16),
#  ('wbfm', 17),
#  ('wbfm', 18),
#  ('wbfm', 19),
#  ('wbfm', 20),
#  ('am-dsb', -20),
#  ('am-dsb', -19),
#  ('am-dsb', -18),
#  ('am-dsb', -17),
#  ('am-dsb', -16),
#  ('am-dsb', -15),
#  ('am-dsb', -14),
#  ('am-dsb', -13),
#  ('am-dsb', -12),
#  ('am-dsb', -11),
#  ('am-dsb', -10),
#  ('am-dsb', -9),
#  ('am-dsb', -8),
#  ('am-dsb', -7),
#  ('am-dsb', -6),
#  ('am-dsb', -5),
#  ('am-dsb', -4),
#  ('am-dsb', -3),
#  ('am-dsb', -2),
#  ('am-dsb', -1),
#  ('am-dsb', 0),
#  ('am-dsb', 1),
#  ('am-dsb', 2),
#  ('am-dsb', 3),
#  ('am-dsb', 4),
#  ('am-dsb', 5),
#  ('am-dsb', 6),
#  ('am-dsb', 7),
#  ('am-dsb', 8),
#  ('am-dsb', 9),
#  ('am-dsb', 10),
#  ('am-dsb', 11),
#  ('am-dsb', 12),
#  ('am-dsb', 13),
#  ('am-dsb', 14),
#  ('am-dsb', 15),
#  ('am-dsb', 16),
#  ('am-dsb', 17),
#  ('am-dsb', 18),
#  ('am-dsb', 19),
#  ('am-dsb', 20)]

# %%
labels = list(X1.keys())

total_examples = 0
for a in labels:
    total_examples = total_examples +  X1[a].shape[0]


l=list(X1.values())


try:
    snrs,mods = map(lambda j: sorted(list(set(map(lambda x: x[j], X1.keys())))), [1,0])
    no_snr = False
except:
    mods = map(lambda j: sorted(list(set(map(lambda x: x[j], X1.keys())))), [1,0])
    no_snr = True


example_size = X1[labels[0]].shape[0]

#print attributes
print("Dataset filename is: ", filename1)

print("Dataset has", len(labels), "unique label pairs")

print("Dataset examples are labelled with the following modulations:", mods)

# print("Dataset examples are labelled with the following SNRs:", snrs)


print("Dataset has", total_examples ,"total examples")

print("A typical example is ", l[0][0].shape ,"in shape and has", example_size,"examples")
# Out:
# Dataset filename is:  datasets_Qoherent_Modrec_Dataset_AGWN.dat
# Dataset has 451 unique label pairs
# Dataset examples are labelled with the following modulations: ['8psk', 'am-dsb', 'am-ssb', 'bpsk', 'gfsk', 'nbfm', 'pam4', 'qam16', 'qam64', 'qpsk', 'wbfm']
# Dataset has 902000 total examples
# A typical example is  (2, 1024) in shape and has 2000 examples

# %%
## to see the keys in the dataset

print(X1.keys())
# Out:
# dict_keys([('bpsk', -20), ('bpsk', -19), ('bpsk', -18), ('bpsk', -17), ('bpsk', -16), ('bpsk', -15), ('bpsk', -14), ('bpsk', -13), ('bpsk', -12), ('bpsk', -11), ('bpsk', -10), ('bpsk', -9), ('bpsk', -8), ('bpsk', -7), ('bpsk', -6), ('bpsk', -5), ('bpsk', -4), ('bpsk', -3), ('bpsk', -2), ('bpsk', -1), ('bpsk', 0), ('bpsk', 1), ('bpsk', 2), ('bpsk', 3), ('bpsk', 4), ('bpsk', 5), ('bpsk', 6), ('bpsk', 7), ('bpsk', 8), ('bpsk', 9), ('bpsk', 10), ('bpsk', 11), ('bpsk', 12), ('bpsk', 13), ('bpsk', 14), ('bpsk', 15), ('bpsk', 16), ('bpsk', 17), ('bpsk', 18), ('bpsk', 19), ('bpsk', 20), ('qpsk', -20), ('qpsk', -19), ('qpsk', -18), ('qpsk', -17), ('qpsk', -16), ('qpsk', -15), ('qpsk', -14), ('qpsk', -13), ('qpsk', -12), ('qpsk', -11), ('qpsk', -10), ('qpsk', -9), ('qpsk', -8), ('qpsk', -7), ('qpsk', -6), ('qpsk', -5), ('qpsk', -4), ('qpsk', -3), ('qpsk', -2), ('qpsk', -1), ('qpsk', 0), ('qpsk', 1), ('qpsk', 2), ('qpsk', 3), ('qpsk', 4), ('qpsk', 5), ('qpsk', 6), ('qpsk', 7), ('qpsk', 8), ('qpsk', 9), ('qpsk', 10), ('qpsk', 11), ('qpsk', 12), ('qpsk', 13), ('qpsk', 14), ('qpsk', 15), ('qpsk', 16), ('qpsk', 17), ('qpsk', 18), ('qpsk', 19), ('qpsk', 20), ('8psk', -20), ('8psk', -19), ('8psk', -18), ('8psk', -17), ('8psk', -16), ('8psk', -15), ('8psk', -14), ('8psk', -13), ('8psk', -12), ('8psk', -11), ('8psk', -10), ('8psk', -9), ('8psk', -8), ('8psk', -7), ('8psk', -6), ('8psk', -5), ('8psk', -4), ('8psk', -3), ('8psk', -2), ('8psk', -1), ('8psk', 0), ('8psk', 1), ('8psk', 2), ('8psk', 3), ('8psk', 4), ('8psk', 5), ('8psk', 6), ('8psk', 7), ('8psk', 8), ('8psk', 9), ('8psk', 10), ('8psk', 11), ('8psk', 12), ('8psk', 13), ('8psk', 14), ('8psk', 15), ('8psk', 16), ('8psk', 17), ('8psk', 18), ('8psk', 19), ('8psk', 20), ('pam4', -20), ('pam4', -19), ('pam4', -18), ('pam4', -17), ('pam4', -16), ('pam4', -15), ('pam4', -14), ('pam4', -13), ('pam4', -12), ('pam4', -11), ('pam4', -10), ('pam4', -9), ('pam4', -8), ('pam4', -7), ('pam4', -6), ('pam4', -5), ('pam4', -4), ('pam4', -3), ('pam4', -2), ('pam4', -1), ('pam4', 0), ('pam4', 1), ('pam4', 2), ('pam4', 3), ('pam4', 4), ('pam4', 5), ('pam4', 6), ('pam4', 7), ('pam4', 8), ('pam4', 9), ('pam4', 10), ('pam4', 11), ('pam4', 12), ('pam4', 13), ('pam4', 14), ('pam4', 15), ('pam4', 16), ('pam4', 17), ('pam4', 18), ('pam4', 19), ('pam4', 20), ('qam16', -20), ('qam16', -19), ('qam16', -18), ('qam16', -17), ('qam16', -16), ('qam16', -15), ('qam16', -14), ('qam16', -13), ('qam16', -12), ('qam16', -11), ('qam16', -10), ('qam16', -9), ('qam16', -8), ('qam16', -7), ('qam16', -6), ('qam16', -5), ('qam16', -4), ('qam16', -3), ('qam16', -2), ('qam16', -1), ('qam16', 0), ('qam16', 1), ('qam16', 2), ('qam16', 3), ('qam16', 4), ('qam16', 5), ('qam16', 6), ('qam16', 7), ('qam16', 8), ('qam16', 9), ('qam16', 10), ('qam16', 11), ('qam16', 12), ('qam16', 13), ('qam16', 14), ('qam16', 15), ('qam16', 16), ('qam16', 17), ('qam16', 18), ('qam16', 19), ('qam16', 20), ('qam64', -20), ('qam64', -19), ('qam64', -18), ('qam64', -17), ('qam64', -16), ('qam64', -15), ('qam64', -14), ('qam64', -13), ('qam64', -12), ('qam64', -11), ('qam64', -10), ('qam64', -9), ('qam64', -8), ('qam64', -7), ('qam64', -6), ('qam64', -5), ('qam64', -4), ('qam64', -3), ('qam64', -2), ('qam64', -1), ('qam64', 0), ('qam64', 1), ('qam64', 2), ('qam64', 3), ('qam64', 4), ('qam64', 5), ('qam64', 6), ('qam64', 7), ('qam64', 8), ('qam64', 9), ('qam64', 10), ('qam64', 11), ('qam64', 12), ('qam64', 13), ('qam64', 14), ('qam64', 15), ('qam64', 16), ('qam64', 17), ('qam64', 18), ('qam64', 19), ('qam64', 20), ('gfsk', -20), ('gfsk', -19), ('gfsk', -18), ('gfsk', -17), ('gfsk', -16), ('gfsk', -15), ('gfsk', -14), ('gfsk', -13), ('gfsk', -12), ('gfsk', -11), ('gfsk', -10), ('gfsk', -9), ('gfsk', -8), ('gfsk', -7), ('gfsk', -6), ('gfsk', -5), ('gfsk', -4), ('gfsk', -3), ('gfsk', -2), ('gfsk', -1), ('gfsk', 0), ('gfsk', 1), ('gfsk', 2), ('gfsk', 3), ('gfsk', 4), ('gfsk', 5), ('gfsk', 6), ('gfsk', 7), ('gfsk', 8), ('gfsk', 9), ('gfsk', 10), ('gfsk', 11), ('gfsk', ...

# %%
#### SELECTING EXAMPLES

## setting modulations

mod_1 = 'bpsk' ### select a modulation for the first plot
mod_2 = 'qam64' ### select a modulation for the second plot


## setting SNR - NOTE: ONLY WORKS ON DATASET WITH CONFIGURED SNRS

snr_1 = 2 ### select an SNR for the first plot
snr_2 = 18 ### select an SNR for the second plot

# %%
if no_snr == True:
    array1 = X1[(mod_1, )] # Replace label with one that that exists in dataset
    array2 = X1[(mod_2, )] # Replace label with one that that exists in dataset
else:
    array1 = X1[(mod_1, snr_1)] # Replace label with one that that exists in dataset
    array2 = X1[(mod_2, snr_2)] # Replace label with one that that exists in dataset


#print(array1[0, 0, :])
length = array1[0, 0, :].shape[0]

t = np.arange(0, length, 1)

fig, axs = plt.subplots(2, 1)

print(example_size)


#chooses random examples from the list of examples in the class to plot
plot1_idx = random.randint(0,example_size) # select random example that exists in dataset for first plot
plot2_idx = random.randint(0,example_size)  # select random example that exists in dataset for second plot

title1 = 'Modulation: ',mod_1,'. SNR: ',snr_1,'. Example: ',plot1_idx
axs[0].plot(t, array1[plot1_idx, 0, :], t, array1[plot1_idx, 1, :])
axs[0].set_xlim(0, length)
axs[0].set_xlabel('time sample')
axs[0].set_ylabel('Signal 1')
axs[0].set_title(title1)
axs[0].grid(True)

title2='Modulation: ',mod_2,'. SNR: ',snr_2,'. Example: ',plot2_idx
axs[1].plot(t, array2[plot2_idx, 0, :], t, array2[plot2_idx, 1, :])
axs[1].set_xlim(0, length)
axs[1].set_xlabel('time sample')
axs[1].set_ylabel('signal 2')
axs[1].set_title(title2)
axs[1].grid(True)


fig.tight_layout()
plt.show()
# Out:
# 2000
